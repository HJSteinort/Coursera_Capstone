# %% [markdown]
# # Coursera Capstone Notebook
# ## Week 1

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ## Week 2

# %% [markdown]
# ### Scraping Data

# %%
# import necessary libraries for scraping
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# create dataframe from wikipedia table with BeatifulSoup
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
req = requests.get(url)

soup = BeautifulSoup(req.content,'lxml')
table = soup.find_all('table')[0]

dfs = pd.read_html(str(table))
dfs
df = dfs[0]
df[0:10]
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor
# 7      M7A  Downtown Toronto      Queen's Park
# 8      M8A      Not assigned      Not assigned
# 9      M9A      Queen's Park      Not assigned

# %%
# assign borough name to 'not assigned' neighbourhoods
na = df.index[df['Neighbourhood'] == 'Not assigned'].tolist()

df.loc[na, 'Neighbourhood'] = df.loc[na, 'Borough']
df[0:10]
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor
# 7      M7A  Downtown Toronto      Queen's Park
# 8      M8A      Not assigned      Not assigned
# 9      M9A      Queen's Park      Queen's Park

# %%
# drop rows containing 'not assigned' boroughs
na_b = df[df['Borough'] == 'Not assigned'].index

df.drop(na_b , inplace=True)
df[0:10]
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park
# 9       M9A      Queen's Park      Queen's Park
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern
# 13      M3B        North York   Don Mills North

# %%
# group neighbourhoods within the same postal code comma separated
df = df.groupby(['Postcode','Borough'], sort=False, as_index=False).agg( ', '.join)
df[0:10]
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto                      Harbourfront
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A  Downtown Toronto                      Queen's Park
# 5      M9A      Queen's Park                      Queen's Park
# 6      M1B       Scarborough                    Rouge, Malvern
# 7      M3B        North York                   Don Mills North
# 8      M4B         East York   Woodbine Gardens, Parkview Hill
# 9      M5B  Downtown Toronto          Ryerson, Garden District

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Neighbourhood Summarization & Location Extraction

# %%
# read predefined .csv-file containing latitude and longitude data
df_l = pd.read_csv(r"https://cocl.us/Geospatial_data")
df_l.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
print(df_l.shape)
df_l.head()
# Out:
# (103, 3)
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
# map latitude and longitude data to previously created dataframe
df['Latitude'] = df['Postcode'].map(df_l.set_index('Postcode')['Latitude'])
df['Longitude'] = df['Postcode'].map(df_l.set_index('Postcode')['Longitude'])
df[0:10]
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto                      Harbourfront  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A  Downtown Toronto                      Queen's Park  43.662301
# 5      M9A      Queen's Park                      Queen's Park  43.667856
# 6      M1B       Scarborough                    Rouge, Malvern  43.806686
# 7      M3B        North York                   Don Mills North  43.745906
# 8      M4B         East York   Woodbine Gardens, Parkview Hill  43.706397
# 9      M5B  Downtown Toronto          Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %% [markdown]
# ### Neighbourhood Exploration & Clustering

# %%
# install folium
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.0.1-py_0        conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# import necessary libraries
from geopy.geocoders import Nominatim
import folium

# %%
# get geolocation of Toronto by address
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent='my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# **Note:** To recreate the NY-Lab I will again import a dataframe containing the boroughs and neighborhoods of Toronto but without grouping them together by postal code

# %%
# import necessary libraries for scraping
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# create dataframe from wikipedia table with BeatifulSoup
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
req = requests.get(url)

soup = BeautifulSoup(req.content,'lxml')
table = soup.find_all('table')[0]

dfs = pd.read_html(str(table))
df = dfs[0]

# assign borough name to 'not assigned' neighbourhoods
na = df.index[df['Neighbourhood'] == 'Not assigned'].tolist()

df.loc[na, 'Neighbourhood'] = df.loc[na, 'Borough']

# drop rows containing 'not assigned' boroughs
na_b = df[df['Borough'] == 'Not assigned'].index

df.drop(na_b , inplace=True)

# map latitude and longitude from predefined dataframe
df['Latitude'] = df['Postcode'].map(df_l.set_index('Postcode')['Latitude'])
df['Longitude'] = df['Postcode'].map(df_l.set_index('Postcode')['Longitude'])

# get filtered dataframe containing only boroughs within Toronto
neighborhoods = df[df['Borough'].str.contains('Toronto')]

neighborhoods.head()
# Out:
#    Postcode           Borough    Neighbourhood   Latitude  Longitude
# 4       M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 7       M7A  Downtown Toronto     Queen's Park  43.662301 -79.389494
# 16      M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 17      M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 33      M5C  Downtown Toronto   St. James Town  43.651494 -79.375418

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add borough markers to map
for lat, lng, borough, neighbourhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#008000',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define Foursquare credentials and version
CLIENT_ID = 'JQU0HLCVSP2XABMT521CHSJSUX0EWGHWV3TTMVR2YS1MB4WQ'
CLIENT_SECRET = 'JDZEO4RGBZJBIX3IPYXRSNQ1BOH2CIN1OE5SUWEVXTSV10QC'
VERSION = '20180605' # Foursquare API version

# %%
# Copy of the getNearbyVenues-function from the NY-Lab
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# get max. 100 venues in da 500m radius around the borough center
limit = 100
radius = 500

toronto_venues = getNearbyVenues(names=neighborhoods['Neighbourhood'],
                                 latitudes=neighborhoods['Latitude'],
                                 longitudes=neighborhoods['Longitude'],
                                 radius=radius)
# Out:
# Harbourfront
# Queen's Park
# Ryerson
# Garden District
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Dovercourt Village
# Dufferin
# Harbourfront East
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# The Danforth West
# Riverdale
# Design Exchange
# Toronto Dominion Centre
# Brockton
# Exhibition Place
# Parkdale Village
# The Beaches West
# India Bazaar
# Commerce Court
# Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North
# Forest Hill West
# High Park
# The Junction South
# North Toronto West
# The Annex
# North Midtown
# Yorkville
# Parkdale
# Roncesvalles
# Davisville
# Harbord
# University of Toronto
# Runnymede
# Swansea
# Moore Park
# Summerhill East
# Chinatown
# Grange Park
# Kensington Market
# Deer Park
# Forest Hill SE
# Rathnelly
# South Hill
# Summerhill West
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern

# %%
toronto_venues.head()
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Harbourfront               43.65426              -79.360636
# 1  Harbourfront               43.65426              -79.360636
# 2  Harbourfront               43.65426              -79.360636
# 3  Harbourfront               43.65426              -79.360636
# 4  Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653191       -79.357947
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#          Venue Category
# 0                Bakery
# 1           Coffee Shop
# 2  Gym / Fitness Center
# 3                   Spa
# 4            Restaurant

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Adelaide                                                             100
# Bathurst Quay                                                         12
# Berczy Park                                                           56
# Brockton                                                              22
# Business Reply Mail Processing Centre 969 Eastern                     16
# CN Tower                                                              12
# Cabbagetown                                                           44
# Central Bay Street                                                    83
# Chinatown                                                             91
# Christie                                                              17
# Church and Wellesley                                                  81
# Commerce Court                                                       100
# Davisville                                                            33
# Davisville North                                                       8
# Deer Park                                                             16
# Design Exchange                                                      100
# Dovercourt Village                                                    15
# Dufferin                                                              15
# Exhibition Place                                                      22
# First Canadian Place                                                 100
# Forest Hill North                                                      4
# Forest Hill SE                                                        16
# Forest Hill West                                                       4
# Garden District                                                      100
# Grange Park                                                           91
# Harbord                                                               36
# Harbourfront                                                          46
# Harbourfront East                                                    100
# Harbourfront West                                                     12
# High Park                                                             23
# ...                                                                  ...
# Railway Lands                                                         12
# Rathnelly                                                             16
# Richmond                                                             100
# Riverdale                                                             42
# Roncesvalles                                                          13
# Rosedale                                                               4
# Roselawn                                                               1
# Runnymede                                                             37
# Ryerson                                                              100
# South Hill                                                            16
# South Niagara                                                         12
# St. James Town                                                       144
# Stn A PO Boxes 25 The Esplanade                                       95
# Studio District                                                       42
# Summerhill East                                                        4
# Summerhill West                                                       16
# Swansea                                                               37
# The Annex                                                             21
# The Beaches                                                            4
# The Beaches West                                                      19
# The Danforth West                                                     42
# The Junction South                                                    23
# Toronto Dominion Centre                                              100
# Toronto Islands                                                      100
# Trinity                                                               55
# Underground city                                                     100
# Union Station                                                        100
# University of Toronto                                                 36
# Victoria Hotel                                                       100
# Yorkville                                                             21
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# Adelaide                                                              100
# Bathurst Quay                                                          12
# Berczy Park                                                            56
# Brockton                                                               22
# Business Reply Mail Processing Centre 969 Eastern                      16
# CN Tower                                                               12
# Cabbagetown                                                            44
# Central Bay Street                                                     83
# Chinatown                                                              91
# Christie                                                               17
# Church and Wellesley                                                   81
# Commerce Court                                                        100
# Davisville                                                             33
# Davisville North                                                        8
# Deer Park                                                              16
# Design Exchange                                                       100
# Dovercourt Village                                                     15
# Dufferin                                                               15
# Exhibition Place                                                       22
# First Canadian Place                                                  100
# Forest Hill North                                                       4
# Forest Hill SE                                                         16
# Forest Hill West                                                        4
# Garden District                                                       100
# Grange Park                                                            91
# Harbord                                                                36
# Harbourfront                                                           46
# Harbourfront East                                                     100
# Harbourfront West                                                      12
# High Park                                                              23
# ...                                                                   ...
# Railway Lands                                                          12
# Rathnelly                                                              16
# Richmond                                                              100
# Riverdale                                                              42
# Roncesvalles                                                           13
# Rosedale                                                                4
# Roselawn                                                                1
# Runnymede                                                              37
# Ryerson                                                               100
# South Hill                                                             16
# South Niagara                                                          12
# St. James Town                                                        144
# Stn A PO Boxes 25 The Esplanade                                        95
# Studio District                                                        42
# Summerhill East                                                         4
# Summerhill West                                                        16
# Swansea                                                                37
# The Annex                                                              21
# The Beaches                                                             4
# The Beaches West                                                       19
# The Danforth West                                                      42
# The Junction South                                                     23
# Toronto Dominion Centre                                               100
# Toronto Islands                                                       100
# Trinity                                                                55
# Underground city                                                      100
# Union Station                                                         100
# University of Toronto                                                  36
# Victoria Hotel                                                        100
# Yorkville                                                              21
#
#                                                    Venue  Venue Latitude  \
# Neighborhood
# Adelaide                                             100             100
# Bathurst Quay                                         12              12
# Berczy Park                                           56              56
# Brockton                                              22              22
# Business Reply Mail Processing Centre 969 Eastern     16              16
# CN Tower                                              12              12
# Cabbagetown                                           44              44
# Central Bay Street                                    83              83
# Chinatown                                             91              91
# Christie                                              17              17
# Church and Wellesley                                  81              81
# Commerce Court                                       100             100
# Davisville                                            33              33
# Davisville North                                       8               8
# Deer Park                                             16              16
# Design Exchange                                      100             100
# Dovercourt Village                                    15              15
# Dufferin                                              15              15
# Exhibition Place                                      22              22
# First Canadian Place                                 100             100
# Forest Hill North                                      4               4
# Forest Hill SE                                        16              16
# Forest Hill West                                       4               4
# Garden District                                      100             100
# Grange Park                                           91              91
# Harbord                                               36              36
# Harbourfront                                          46              46
# Harbourfront East                                    100             100
# Harbourfront West                                     12              12
# High Park                                             23              23
# ...                                                  ...             ...
# Railway Lands                                         12              12
# Rathnelly                                             16              16
# Richmond                                             100             100
# Riverdale                                             42              42
# Roncesvalles                                          13              13
# Rosedale                                               4               4
# Roselawn                                               1               1
# Runnymede                                             37              37
# Ryerson                                              100             100
# South Hill                                            16              16
# South Niagara                                         12              12
# St. James Town                                       144             144
# Stn A PO Boxes 25 The Esplanade                       95              95
# Studio District                                       42              42
# Summerhill East                                        4               4
# Summerhill West                                       16              16
# Swansea                                               37              37
# The Annex                                             21              21
# The Beaches                                            4               4
# The Beaches West                                      19              19
# The Danforth West                                     42              42
# The Junction South                                    23              23
# Toronto Dominion Centre                              100             100
# Toronto Islands                                      100             100
# Trinity                                               55              55
# Underground city                                     100             100
# Union Station                                        100             100
# University of Toronto                                 36              36
# Victoria Hotel                                       100             100
# Yorkville                                             21              21
#
#                                                    Venue Longitude  \
# Neighborhood
# Adelaide                                                       100
# Bathurst Quay                                                   12
# Berczy Park                                                     56
# Brockton                                                        22
# Business Reply Mail Processing Centre 969 Eastern               16
# CN Tower                                                        12
# Cabbagetown                                                     44
# Central Bay Street                                              83
# Chinatown                                                       91
# Christie                                                        17
# Church and Wellesley                                            81
# Commerce Court                                                 100
# Davisville                                                      33
# Davisville North                                                 8
# Deer Park                                                       16
# Design Exchange                                                100
# Dovercourt Village                                              15
# Dufferin                                                        15
# Exhibition Place                                                22
# First Canadian Place                                           100
# Forest Hill North                                                4
# Forest Hill SE                                                  16
# Forest Hill West                                                 4
# Garden District                                                100
# Grange Park                                                     91
# Harbord                                                         36
# Harbourfront                                                    46
# Harbourfront East                                              100
# Harbourfront West                                               12
# High Park                                                       23
# ...                                                            ...
# Railway Lands                                                   12
# Rathnelly                                                       16
# Richmond                                                       100
# Riverdale                                                       42
# Roncesvalles                                                    13
# Rosedale                                                         4
# Roselawn                                                         1
# Runnymede                                                       37
# Ryerson                                                        100
# South Hill                                                      16
# South Niagara                                                   12
# St. James Town                                                 144
# Stn A PO Boxes 25 The Esplanade                                 95
# Studio District                                                 42
# Summerhill East                                                  4
# Summerhill West                                                 16
# Swansea                                                         37
# The Annex                                                       21
# The Beaches                                                      4
# The Beaches West                                                19
# The Danforth West                                               42
# The Junction South                                              23
# Toronto Dominion Centre                                        100
# Toronto Islands                                                100
# Trinity                                                         55
# Underground city                                               100
# Union Station                                                  100
# University of Toronto                                           36
# Victoria Hotel                                                 100
# Yorkville                                                       21
#
#                                                    Venue Category
# Neighborhood
# Adelaide                                                      100
# Bathurst Quay                                                  12
# Berczy Park                                                    56
# Brockton                                                       22
# Business Reply Mail Processing Centre 969 Eastern              16
# CN Tower                                                       12
# Cabbagetown                                                    44
# Central Bay Street                                             83
# Chinatown                                                      91
# Christie                                                       17
# Church and Wellesley                                           81
# Commerce Court                                                100
# Davisville                                                     33
# Davisville North                                                8
# Deer Park                                                      16
# Design Exchange                                               100
# Dovercourt Village                                             15
# Dufferin                                                       15
# Exhibition Place                                               22
# First Canadian Place                                          100
# Forest Hill North                                               4
# Forest Hill SE                                                 16
# Forest Hill West                                                4
# Garden District                                               100
# Grange Park                                                    91
# Harbord                                                        36
# Harbourfront                                                   46
# Harbourfront East                                             100
# Harbourfront West                                              12
# High Park                                                      23
# ...                                                           ...
# Railway Lands                                                  12
# Rathnelly                                                      16
# Richmond                                                      100
# Riverdale                                                      42
# Roncesvalles                                                   13
# Rosedale                                                        4
# Roselawn                                                        1
# Runnymede                                                      37
# Ryerson                                                       100
# South Hill                                                     16
# South Niagara                                                  12
# St. James Town                                                144
# Stn A PO Boxes 25 The Esplanade                                95
# Studio District                                                42
# Summerhill East                                                 4
# Summerhill West                                                16
# Swansea                                                        37
# The Annex                                                      21
# The Beaches                                                     4
# The Beaches West                                               19
# The Danforth West                                              42
# The Junction South                                             23
# Toronto Dominion Centre                                       100
# Toronto Islands                                               100
# Trinity                                                        55
# Underground city                                              100
# Union Station                                                 100
# University of Toronto                                          36
# Victoria Hotel                                                100
# Yorkville                                                      21
#
# [73 rows x 6 columns]

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to frame
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

# group by neighborhood name and get mean frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Afghan Restaurant  \
# 0                                            Adelaide           0.000000
# 1                                       Bathurst Quay           0.000000
# 2                                         Berczy Park           0.000000
# 3                                            Brockton           0.000000
# 4   Business Reply Mail Processing Centre 969 Eastern           0.000000
# 5                                            CN Tower           0.000000
# 6                                         Cabbagetown           0.000000
# 7                                  Central Bay Street           0.000000
# 8                                           Chinatown           0.000000
# 9                                            Christie           0.000000
# 10                               Church and Wellesley           0.012346
# 11                                     Commerce Court           0.000000
# 12                                         Davisville           0.000000
# 13                                   Davisville North           0.000000
# 14                                          Deer Park           0.000000
# 15                                    Design Exchange           0.000000
# 16                                 Dovercourt Village           0.000000
# 17                                           Dufferin           0.000000
q
# 0         Coffee Shop  0.07
# 1        Cocktail Bar  0.05
# 2          Steakhouse  0.04
# 3  Seafood Restaurant  0.04
# 4              Bakery  0.04
#
#
# ---- Brockton ----
#                     Venue  Freq
# 0                    Café  0.14
# 1          Breakfast Spot  0.09
# 2             Coffee Shop  0.09
# 3           Grocery Store  0.05
# 4  Furniture / Home Store  0.05
#
#
# ---- Business Reply Mail Processing Centre 969 Eastern ----
#                   Venue  Freq
# 0                   Spa  0.06
# 1         Auto Workshop  0.06
# 2            Smoke Shop  0.06
# 3                  Park  0.06
# 4  Fast Food Restaurant  0.06
#
#
# ---- CN Tower ----
#               Venue  Freq
# 0    Airport Lounge  0.17
# 1   Airport Service  0.17
# 2  Airport Terminal  0.17
# 3   Harbor / Marina  0.08
# 4           Airport  0.08
#
#
# ---- Cabbagetown ----
#                 Venue  Freq
# 0         Coffee Shop  0.07
# 1          Restaurant  0.07
# 2                 Pub  0.05
# 3                Café  0.05
# 4  Italian Restaurant  0.05
#
#
# ---- Central Bay Street ----
#                 Venue  Freq
# 0         Coffee Shop  0.16
# 1                Café  0.05
# 2  Italian Restaurant  0.05
# 3      Sandwich Place  0.04
# 4      Ice Cream Shop  0.04
#
#
# ---- Chinatown ----
#                            Venue  Freq
# 0                           Café  0.07
# 1          Vietnamese Restaurant  0.05
# 2  Vegetarian / Vegan Restaurant  0.05
# 3             Chinese Restaurant  0.04
# 4            Dumpling Restaurant  0.04
#
#
# ---- Christie ----
#            Venue  Freq
# 0  Grocery Store  0.18
# 1           Café  0.18
# 2           Park  0.12
# 3     Restaurant  0.06
# 4    Candy Store  0.06
#
#
# ---- Church and Wellesley ----
#                  Venue  Freq
# 0          Coffee Shop  0.09
# 1  Japanese Restaurant  0.05
# 2     Sushi Restaurant  0.05
# 3              Gay Bar  0.04
# 4           Restaurant  0.04
#
#
# ---- Commerce Court ----
#                 Venue  Freq
# 0         Coffee Shop  0.12
# 1                Café  0.07
# 2               Hotel  0.06
# 3          Restaurant  0.05
# 4  Italian Restaurant  0.03
#
#
# ---- Davisville ----
#             Venue  Freq
# 0  Sandwich Place  0.09
# 1    Dessert Shop  0.09
# 2     Pizza Place  0.06
# 3            Café  0.06
# 4             Gym  0.06
#
#
# ---- Davisville North ----
#                Venue  Freq
# 0     Breakfast Spot  0.12
# 1              Hotel  0.12
# 2   Department Store  0.12
# 3  Food & Drink Shop  0.12
# 4     Sandwich Place  0.12
#
#
# ---- Deer Park ----
#               Venue  Freq
# 0               Pub  0.12
# 1       Coffee Shop  0.12
# 2              Park  0.06
# 3  Sushi Restaurant  0.06
# 4       Supermarket  0.06
#
#
# ---- Design Exchange ----
#                 Venue  Freq
# 0         Coffee Shop  0.14
# 1               Hotel  0.08
# 2                Café  0.07
# 3          Steakhouse  0.03
# 4  Italian Restaurant  0.03
#
#
# ---- Dovercourt Village ----
#          Venue  Freq
# 0       Bakery  0.13
# 1     Pharmacy  0.13
# 2  Music Venue  0.07
# 3         Café  0.07
# 4  Supermarket  0.07
#
#
# ---- Dufferin ----
#          Venue  Freq
# 0       Bakery  0.13
# 1     Pharmacy  0.13
# 2  Music Venue  0.07
# 3         Café  0.07
# 4  Supermarket  0.07
#
#
# ---- Exhibition Place ----
#                     Venue  Freq
# 0                    Café  0.14
# 1          Breakfast Spot  0.09
# 2             Coffee Shop  0.09
# 3           Grocery Store  0.05
# 4  Furniture / Home Store  0.05
#
#
# ---- First Canadian Place ----
#          Venue  Freq
# 0  Coffee Shop  0.13
# 1         Café  0.07
# 2   Restaurant  0.04
# 3        Hotel  0.04
# 4          Gym  0.04
#
#
# ---- Forest Hill North ----
#                Venue  Freq
# 0      Jewelry Store  0.25
# 1              Trail  0.25
# 2   Sushi Restaurant  0.25
# 3           Bus Line  0.25
# 4  Afghan Restaurant  0.00
#
#
# ---- Forest Hill SE ----
#               Venue  Freq
# 0               Pub  0.12
# 1       Coffee Shop  0.12
# 2              Park  0.06
# 3  Sushi Restaurant  0.06
# 4       Supermarket  0.06
#
#
# ---- Forest Hill West ----
#                Venue  Freq
# 0      Jewelry Store  0.25
# 1              Trail  0.25
# 2   Sushi Restaurant  0.25
# 3           Bus Line  0.25
# 4  Afghan Restaurant  0.00
#
#
# ---- Garden District ----
#                  Venue  Freq
# 0          Coffee Shop  0.10
# 1       Clothing Store  0.05
# 2       Cosmetics Shop  0.04
# 3                 Café  0.04
# 4  Japanese Restaurant  0.03
#
#
# ---- Grange Park ----
#                            Venue  Freq
# 0                           Café  0.07
# 1          Vietnamese Restaurant  0.05
# 2  Vegetarian / Vegan Restaurant  0.05
# 3             Chinese Restaurant  0.04
# 4            Dumpling Restaurant  0.04
#
#
# ---- Harbord ----
#                  Venue  Freq
# 0                 Café  0.17
# 1  Japanese Restaurant  0.06
# 2       Sandwich Place  0.06
# 3            Bookstore  0.06
# 4           Restaurant  0.06
#
#
# ---- Harbourfront ----
#                 Venue  Freq
# 0         Coffee Shop  0.15
# 1                 Pub  0.07
# 2              Bakery  0.07
# 3                Park  0.07
# 4  Mexican Restaurant  0.04
#
#
# ---- Harbourfront East ----
#          Venue  Freq
# 0  Coffee Shop  0.12
# 1     Aquarium  0.05
# 2         Café  0.04
# 3        Hotel  0.04
# 4      Brewery  0.03
#
#
# ---- Harbourfront West ----
#               Venue  Freq
# 0    Airport Lounge  0.17
# 1   Airport Service  0.17
# 2  Airport Terminal  0.17
# 3   Harbor / Marina  0.08
# 4           Airport  0.08
#
#
# ---- High Park ----
#                 Venue  Freq
# 0     Thai Restaurant  0.09
# 1                Café  0.09
# 2  Mexican Restaurant  0.09
# 3                 Bar  0.09
# 4       Grocery Store  0.04
#
#
# ---- India Bazaar ----
#                   Venue  Freq
# 0                  Park  0.11
# 1         Movie Theater  0.05
# 2    Italian Restaurant  0.05
# 3  Fast Food Restaurant  0.05
# 4               Brewery  0.05
#
#
# ---- Island airport ----
#               Venue  Freq
# 0    Airport Lounge  0.17
# 1   Airport Service  0.17
# 2  Airport Terminal  0.17
# 3   Harbor / Marina  0.08
# 4           Airport  0.08
#
#
# ---- Kensington Market ----
#                            Venue  Freq
# 0                           Café  0.07
# 1          Vietnamese Restaurant  0.05
# 2  Vegetarian / Vegan Restaurant  0.05
# 3             Chinese Restaurant  0.04
# 4            Dumpling Restaurant  0.04
#
#
# ---- King ----
#               Venue  Freq
# 0       Coffee Shop  0.07
# 1              Café  0.04
# 2               Bar  0.04
# 3        Steakhouse  0.04
# 4  Asian Restaurant  0.03
#
#
# ---- King and Spadina ----
#               Venue  Freq
# 0    Airport Lounge  0.17
# 1   Airport Service  0.17
# 2  Airport Terminal  0.17
# 3   Harbor / Marina  0.08
# 4           Airport  0.08
#
#
# ---- Lawrence Park ----
#                              Venue  Freq
# 0                             Park  0.33
# 1                      Swim School  0.33
# 2                         Bus Line  0.33
# 3                Afghan Restaurant  0.00
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ---- Little Portugal ----
#                    Venue  Freq
# 0                    Bar  0.15
# 1       Asian Restaurant  0.05
# 2             Restaurant  0.05
# 3            Pizza Place  0.04
# 4  Vietnamese Restaurant  0.04
#
#
# ---- Moore Park ----
#                  Venue  Freq
# 0         Tennis Court  0.25
# 1                 Park  0.25
# 2           Playground  0.25
# 3           Restaurant  0.25
# 4  Monument / Landmark  0.00
#
#
# ---- North Midtown ----
#             Venue  Freq
# 0            Café  0.14
# 1  Sandwich Place  0.14
# 2     Coffee Shop  0.10
# 3  Cosmetics Shop  0.05
# 4             Pub  0.05
#
#
# ---- North Toronto West ----
#                   Venue  Freq
# 0        Clothing Store  0.15
# 1   Sporting Goods Shop  0.10
# 2           Coffee Shop  0.10
# 3           Yoga Studio  0.05
# 4  Gym / Fitness Center  0.05
#
#
# ---- Parkdale ----
#                 Venue  Freq
# 0           Gift Shop  0.15
# 1         Coffee Shop  0.08
# 2                 Bar  0.08
# 3  Italian Restaurant  0.08
# 4      Breakfast Spot  0.08
#
#
# ---- Parkdale Village ----
#                     Venue  Freq
# 0                    Café  0.14
# 1          Breakfast Spot  0.09
# 2             Coffee Shop  0.09
# 3           Grocery Store  0.05
# 4  Furniture / Home Store  0.05
#
#
# ---- Queen's Park ----
#               Venue  Freq
# 0       Coffee Shop  0.28
# 1              Park  0.05
# 2               Gym  0.05
# 3       Yoga Studio  0.03
# 4  Sushi Restaurant  0.03
#
#
# ---- Railway Lands ----
#               Venue  Freq
# 0    Airport Lounge  0.17
# 1   Airport Service  0.17
# 2  Airport Terminal  0.17
# 3   Harbor / Marina  0.08
# 4           Airport  0.08
#
#
# ---- Rathnelly ----
#               Venue  Freq
# 0               Pub  0.12
# 1       Coffee Shop  0.12
# 2              Park  0.06
# 3  Sushi Restaurant  0.06
# 4       Supermarket  0.06
#
#
# ---- Richmond ----
#               Venue  Freq
# 0       Coffee Shop  0.07
# 1              Café  0.04
# 2               Bar  0.04
# 3        Steakhouse  0.04
# 4  Asian Restaurant  0.03
#
#
# ---- Riverdale ----
#                     Venue  Freq
# 0        Greek Restaurant  0.21
# 1             Coffee Shop  0.10
# 2          Ice Cream Shop  0.07
# 3      Italian Restaurant  0.07
# 4  Furniture / Home Store  0.05
#
#
# ---- Roncesvalles ----
#                 Venue  Freq
# 0           Gift Shop  0.15
# 1         Coffee Shop  0.08
# 2                 Bar  0.08
# 3  Italian Restaurant  0.08
# 4      Breakfast Spot  0.08
#
#
# ---- Rosedale ----
#                  Venue  Freq
# 0                 Park  0.50
# 1           Playground  0.25
# 2                Trail  0.25
# 3    Afghan Restaurant  0.00
# 4  Monument / Landmark  0.00
#
#
# ---- Roselawn ----
#                Venue  Freq
# 0             Garden   1.0
# 1  Afghan Restaurant   0.0
# 2      Movie Theater   0.0
# 3             Lounge   0.0
# 4   Malay Restaurant   0.0
#
#
# ---- Runnymede ----
#                 Venue  Freq
# 0                Café  0.08
# 1         Coffee Shop  0.08
# 2    Sushi Restaurant  0.05
# 3  Italian Restaurant  0.05
# 4         Pizza Place  0.05
#
#
# ---- Ryerson ----
#                  Venue  Freq
# 0          Coffee Shop  0.10
# 1       Clothing Store  0.05
# 2       Cosmetics Shop  0.04
# 3                 Café  0.04
# 4  Japanese Restaurant  0.03
#
#
# ---- South Hill ----
#               Venue  Freq
# 0               Pub  0.12
# 1       Coffee Shop  0.12
# 2              Park  0.06
# 3  Sushi Restaurant  0.06
# 4       Supermarket  0.06
#
#
# ---- South Niagara ----
#               Venue  Freq
# 0    Airport Lounge  0.17
# 1   Airport Service  0.17
# 2  Airport Terminal  0.17
# 3   Harbor / Marina  0.08
# 4           Airport  0.08
#
#
# ---- St. James Town ----
#                 Venue  Freq
# 0         Coffee Shop  0.06
# 1                Café  0.06
# 2          Restaurant  0.06
# 3              Bakery  0.03
# 4  Italian Restaurant  0.03
#
#
# ---- Stn A PO Boxes 25 The Esplanade ----
#                  Venue  Freq
# 0          Coffee Shop  0.12
# 1                 Café  0.04
# 2   Italian Restaurant  0.03
# 3  Japanese Restaurant  0.03
# 4                Hotel  0.03
#
#
# ---- Studio District ----
#                  Venue  Freq
# 0                 Café  0.10
# 1          Coffee Shop  0.07
# 2              Brewery  0.05
# 3   Italian Restaurant  0.05
# 4  American Restaurant  0.05
#
#
# ---- Summerhill East ----
#                  Venue  Freq
# 0         Tennis Court  0.25
# 1                 Park  0.25
# 2           Playground  0.25
# 3           Restaurant  0.25
# 4  Monument / Landmark  0.00
#
#
# ---- Summerhill West ----
#               Venue  Freq
# 0               Pub  0.12
# 1       Coffee Shop  0.12
# 2              Park  0.06
# 3  Sushi Restaurant  0.06
# 4       Supermarket  0.06
#
#
# ---- Swansea ----
#                 Venue  Freq
# 0                Café  0.08
# 1         Coffee Shop  0.08
# 2    Sushi Restaurant  0.05
# 3  Italian Restaurant  0.05
# 4         Pizza Place  0.05
#
#
# ---- The Annex ----
#             Venue  Freq
# 0            Café  0.14
# 1  Sandwich Place  0.14
# 2     Coffee Shop  0.10
# 3  Cosmetics Shop  0.05
# 4             Pub  0.05
#
#
# ---- The Beaches ----
#                  Venue  Freq
# 0    Health Food Store  0.25
# 1                  Pub  0.25
# 2                Trail  0.25
# 3    Afghan Restaurant  0.00
# 4  Monument / Landmark  0.00
#
#
# ---- The Beaches West ----
#                   Venue  Freq
# 0                  Park  0.11
# 1         Movie Theater  0.05
# 2    Italian Restaurant  0.05
# 3  Fast Food Restaurant  0.05
# 4               Brewery  0.05
#
#
# ---- The Danforth West ----
#                     Venue  Freq
# 0        Greek Restaurant  0.21
# 1             Coffee Shop  0.10
# 2          Ice Cream Shop  0.07
# 3      Italian Restaurant  0.07
# 4  Furniture / Home Store  0.05
#
#
# ---- The Junction South ----
#                 Venue  Freq
# 0     Thai Restaurant  0.09
# 1                Café  0.09
# 2  Mexican Restaurant  0.09
# 3                 Bar  0.09
# 4       Grocery Store  0.04
#
#
# ---- Toronto Dominion Centre ----
#                 Venue  Freq
# 0         Coffee Shop  0.14
# 1               Hotel  0.08
# 2                Café  0.07
# 3          Steakhouse  0.03
# 4  Italian Restaurant  0.03
#
#
# ---- Toronto Islands ----
#          Venue  Freq
# 0  Coffee Shop  0.12
# 1     Aquarium  0.05
# 2         Café  0.04
# 3        Hotel  0.04
# 4      Brewery  0.03
#
#
# ---- Trinity ----
#                    Venue  Freq
# 0                    Bar  0.15
# 1       Asian Restaurant  0.05
# 2             Restaurant  0.05
# 3            Pizza Place  0.04
# 4  Vietnamese Restaurant  0.04
#
#
# ---- Underground city ----
#          Venue  Freq
# 0  Coffee Shop  0.13
# 1         Café  0.07
# 2   Restaurant  0.04
# 3        Hotel  0.04
# 4          Gym  0.04
#
#
# ---- Union Station ----
#          Venue  Freq
# 0  Coffee Shop  0.12
# 1     Aquarium  0.05
# 2         Café  0.04
# 3        Hotel  0.04
# 4      Brewery  0.03
#
#
# ---- University of Toronto ----
#                  Venue  Freq
# 0                 Café  0.17
# 1  Japanese Restaurant  0.06
# 2       Sandwich Place  0.06
# 3            Bookstore  0.06
# 4           Restaurant  0.06
#
#
# ---- Victoria Hotel ----
#                 Venue  Freq
# 0         Coffee Shop  0.12
# 1                Café  0.07
# 2               Hotel  0.06
# 3          Restaurant  0.05
# 4  Italian Restaurant  0.03
#
#
# ---- Yorkville ----
#             Venue  Freq
# 0            Café  0.14
# 1  Sandwich Place  0.14
# 2     Coffee Shop  0.10
# 3  Cosmetics Shop  0.05
# 4             Pub  0.05

# %% [markdown]
# The analysis proposes for example that there is an **airport** in the **Bathurst Quay neighborhood**.
# Also there might be a small **Japanese community** in the **Church and Wellesley neighborhood** due to the highest frequency of Japanese and Sushi restaurants

# %%
# copy of the return_most_common_venues function from NY-Lab

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# top 10 venues per neighborhood

import numpy as np

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                           Adelaide           Coffee Shop
# 1                                      Bathurst Quay        Airport Lounge
# 2                                        Berczy Park           Coffee Shop
# 3                                           Brockton                  Café
# 4  Business Reply Mail Processing Centre 969 Eastern            Skate Park
#
#   2nd Most Common Venue 3rd Most Common Venue   4th Most Common Venue  \
# 0                  Café                   Bar              Steakhouse
# 1       Airport Service      Airport Terminal                 Airport
# 2          Cocktail Bar    Seafood Restaurant          Farmers Market
# 3           Coffee Shop        Breakfast Spot  Furniture / Home Store
# 4               Brewery      Recording Studio    Fast Food Restaurant
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0      Asian Restaurant           Burger Joint                 Hotel
# 1    Airport Food Court               Boutique       Harbor / Marina
# 2            Steakhouse                 Bakery                  Café
# 3             Pet Store  Performing Arts Venue    Italian Restaurant
# 4        Farmers Market          Burrito Place         Auto Workshop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Sushi Restaurant        Clothing Store        Thai Restaurant
# 1         Boat or Ferry      Sculpture Garden            Yoga Studio
# 2           Cheese Shop              Beer Bar           Liquor Store
# 3          Intersection                   Gym            Yoga Studio
# 4           Pizza Place                   Spa                 Garden

# %%
from sklearn.cluster import KMeans

# set number of clusters
k = 4

# extract onehot encoded features
toronto_grouped_clustered = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=k, random_state=0).fit(toronto_grouped_clustered)

# merge toronto_grouped with neighborhoods to add latitude/longitude for each neighborhood
toronto_merged = neighborhoods
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged
# Out:
#     Postcode           Borough  \
# 4        M5A  Downtown Toronto
# 7        M7A  Downtown Toronto
# 16       M5B  Downtown Toronto
# 17       M5B  Downtown Toronto
# 33       M5C  Downtown Toronto
# 46       M4E      East Toronto
# 47       M5E  Downtown Toronto
# 56       M5G  Downtown Toronto
# 57       M6G  Downtown Toronto
# 67       M5H  Downtown Toronto
# 68       M5H  Downtown Toronto
# 69       M5H  Downtown Toronto
# 70       M6H      West Toronto
# 71       M6H      West Toronto
# 82       M5J  Downtown Toronto
# 83       M5J  Downtown Toronto
# 84       M5J  Downtown Toronto
# 85       M6J      West Toronto
# 86       M6J      West Toronto
# 96       M4K      East Toronto
# 97       M4K      East Toronto
# 98       M5K  Downtown Toronto
# 99       M5K  Downtown Toronto
# 100      M6K      West Toronto
# 101      M6K      West Toronto
# 102      M6K      West Toronto
# 112      M4L      East Toronto
# 113      M4L      East Toronto
# 114      M5L  Downtown Toronto
# 115      M5L  Downtown Toronto
# ..       ...               ...
# 182      M4S   Central Toronto
# 183      M5S  Downtown Toronto
# 184      M5S  Downtown Toronto
# 185      M6S      West Toronto
# 186      M6S      West Toronto
# 195      M4T   Central Toronto
# 196      M4T   Central Toronto
# 197      M5T  Downtown Toronto
# 198      M5T  Downtown Toronto
# 199      M5T  Downtown Toronto
    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 248                                        Cabbagetown  43.667967 -79.367675
# 249                                     St. James Town  43.667967 -79.367675
# 250                               First Canadian Place  43.648429 -79.382280
# 251                                   Underground city  43.648429 -79.382280
# 261                               Church and Wellesley  43.665860 -79.383160
# 264  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
#
#      Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 4                 0           Coffee Shop                   Park
# 7                 0           Coffee Shop                    Gym
# 16                0           Coffee Shop         Clothing Store
# 17                0           Coffee Shop         Clothing Store
# 33                0           Coffee Shop                   Café
# 46                0     Health Food Store                  Trail
# 47                0           Coffee Shop           Cocktail Bar
# 56                0           Coffee Shop     Italian Restaurant
# 57                0         Grocery Store                   Café
# 67                0           Coffee Shop                   Café
# 68                0           Coffee Shop                   Café
# 69                0           Coffee Shop                   Café
# 70                0                Bakery               Pharmacy
# 71                0                Bakery               Pharmacy
# 82                0           Coffee Shop               Aquarium
# 83                0           Coffee Shop               Aquarium
# 84                0           Coffee Shop               Aquarium
# 85                0                   Bar       Asian Restaurant
# 86                0                   Bar       Asian Restaurant
# 96                0      Greek Restaurant            Coffee Shop
# 97                0      Greek Restaurant            Coffee Shop
# 98                0           Coffee Shop                  Hotel
# 99                0           Coffee Shop                  Hotel
# 100               0                  Café            Coffee Shop
# 101               0                  Café            Coffee Shop
# 102               0                  Café            Coffee Shop
# 112               0                  Park       Sushi Restaurant
# 113               0                  Park       Sushi Restaurant
# 114               0           Coffee Shop                   Café
# 115               0           Coffee Shop                   Café
# ..              ...                   ...                    ...
# 182               0          Dessert Shop         Sandwich Place
# 183               0                  Café     Italian Restaurant
# 184               0                  Café     Italian Restaurant
# 185               0           Coffee Shop                   Café
# 186               0           Coffee Shop                   Café
# 195               3            Restaurant             Playground
# 196               3            Restaurant             Playground
# 197               0                  Café  Vietnamese Restaurant
# 198               0                  Café  Vietnamese Restaurant
# 199               0                  Café  Vietnamese Restaurant
# 210               0           Coffee Shop                    Pub
# 211               0           Coffee Shop                    Pub
# 212               0           Coffee Shop                    Pub
# 213               0           Coffee Shop                    Pub
# 214               0           Coffee Shop                    Pub
# 215               2        Airport Lounge        Airport Service
# 216               2        Airport Lounge        Airport Service
# 217               2        Airport Lounge        Airport Service
# 218               2        Airport Lounge        Airport Service
# 219               2        Airport Lounge        Airport Service
# 220               2        Airport Lounge        Airport Service
# 221               2        Airport Lounge        Airport Service
# 238               3                  Park             Playground
# 239               0           Coffee Shop                   Café
# 248               0            Restaurant            Coffee Shop
# 249               0           Coffee Shop                   Café
# 250               0           Coffee Shop                   Café
# 251               0           Coffee Shop                   Café
# 261               0           Coffee Shop    Japanese Restaurant
# 264               0            Skate Park                Brewery
#
#              3rd Most Common Venue   4th Most Common Venue  \
# 4                              Pub                  Bakery
# 7                             Park             Yoga Studio
# 16                  Cosmetics Shop                    Café
# 17                  Cosmetics Shop                    Café
# 33                      Restaurant                  Bakery
# 46                             Pub             Yoga Studio
# 47              Seafood Restaurant          Farmers Market
# 56                            Café          Sandwich Place
# 57                            Park      Athletics & Sports
# 67                             Bar              Steakhouse
# 68                             Bar              Steakhouse
# 69                             Bar              Steakhouse
# 70                   Grocery Store             Music Venue
# 71                   Grocery Store             Music Venue
# 82                            Café                   Hotel
# 83                            Café                   Hotel
# 84                            Café                   Hotel
# 85                      Restaurant             Men's Store
# 86                      Restaurant             Men's Store
# 96              Italian Restaurant          Ice Cream Shop
# 97              Italian Restaurant          Ice Cream Shop
# 98                            Café                  Lounge
# 99                            Café                  Lounge
# 100                 Breakfast Spot  Furniture / Home Store
# 101                 Breakfast Spot  Furniture / Home Store
# 102                 Breakfast Spot  Furniture / Home Store
# 112                 Ice Cream Shop                 Brewery
# 113                 Ice Cream Shop                 Brewery
# 114                          Hotel              Restaurant
# 115                          Hotel              Restaurant
# ..                             ...                     ...
# 182                    Coffee Shop      Italian Restaurant
# 183                            Bar               Bookstore
# 184                            Bar               Bookstore
# 185               Sushi Restaurant              Restaurant
# 186               Sushi Restaurant              Restaurant
# 195                   Tennis Court                    Park
# 196                   Tennis Court                    Park
# 197  Vegetarian / Vegan Restaurant     Dumpling Restaurant
# 198  Vegetarian / Vegan Restaurant     Dumpling Restaurant
# 199  Vegetarian / Vegan Restaurant     Dumpling Restaurant
# 210                           Park             Pizza Place
# 211                           Park             Pizza Place
# 212                           Park             Pizza Place
# 213                           Park             Pizza Place
# 214                           Park             Pizza Place
# 215               Airport Terminal                 Airport
# 216               Airport Terminal                 Airport
# 217               Airport Terminal                 Airport
# 218               Airport Terminal                 Airport
# 219               Airport Terminal                 Airport
# 220               Airport Terminal                 Airport
# 221               Airport Terminal                 Airport
# 238                          Trail        Department Store
# 239             Seafood Restaurant     Japanese Restaurant
# 248                           Park                    Café
# 249                     Restaurant                  Bakery
# 250                     Restaurant                     Gym
# 251                     Restaurant                     Gym
# 261               Sushi Restaurant                 Gay Bar
# 264               Recording Studio    Fast Food Restaurant
#
#          5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 4           Mexican Restaurant             Restaurant                  Café
# 7                    Nightclub         Sandwich Place         Burrito Place
# 16   Middle Eastern Restaurant    Japanese Restaurant              Tea Room
# 17   Middle Eastern Restaurant    Japanese Restaurant              Tea Room
# 33                        Park                  Diner        Breakfast Spot
# 46                Dessert Shop   Ethiopian Restaurant   Empanada Restaurant
# 47                  Steakhouse                 Bakery                  Café
# 56              Ice Cream Shop    Japanese Restaurant          Burger Joint
# 57          Italian Restaurant                  Diner           Candy Store
# 67            Asian Restaurant           Burger Joint                 Hotel
# 68            Asian Restaurant           Burger Joint                 Hotel
# 69            Asian Restaurant           Burger Joint                 Hotel
# 70                        Café            Supermarket                   Bar
# 71                        Café            Supermarket                   Bar
# 82         Fried Chicken Joint             Restaurant               Brewery
# 83         Fried Chicken Joint             Restaurant               Brewery
# 84         Fried Chicken Joint             Restaurant               Brewery
# 85       Vietnamese Restaurant                   Café           Pizza Place
# 86       Vietnamese Restaurant                   Café           Pizza Place
# 96      Furniture / Home Store            Yoga Studio            Restaurant
# 97      Furniture / Home Store            Yoga Studio            Restaurant
# 98          Seafood Restaurant     Italian Restaurant                   Bar
# 99          Seafood Restaurant     Italian Restaurant                   Bar
# 100                  Pet Store  Performing Arts Venue    Italian Restaurant
# 101                  Pet Store  Performing Arts Venue    Italian Restaurant
# 102                  Pet Store  Performing Arts Venue    Italian Restaurant
# 112                 Steakhouse                    Pub          Liquor Store
# 113                 Steakhouse                    Pub          Liquor Store
# 114                        Gym     Seafood Restaurant    Italian Restaurant
# 115                        Gym     Seafood Restaurant    Italian Restaurant
# ..                         ...                    ...                   ...
# 182                Pizza Place                   Café      Sushi Restaurant
# 183        Japanese Restaurant         Sandwich Place            Restaurant
# 184        Japanese Restaurant         Sandwich Place            Restaurant
# 185                Pizza Place     Italian Restaurant     Electronics Store
# 186                Pizza Place     Italian Restaurant     Electronics Store
# 195    Comfort Food Restaurant       Department Store   Empanada Restaurant
# 196    Comfort Food Restaurant       Department Store   Empanada Restaurant
# 197                Coffee Shop     Chinese Restaurant    Mexican Restaurant
# 198                Coffee Shop     Chinese Restaurant    Mexican Restaurant
# 199                Coffee Shop     Chinese Restaurant    Mexican Restaurant
# 210         Light Rail Station           Liquor Store            Sports Bar
# 211         Light Rail Station           Liquor Store            Sports Bar
# 212         Light Rail Station           Liquor Store            Sports Bar
# 213         Light Rail Station           Liquor Store            Sports Bar
# 214         Light Rail Station           Liquor Store            Sports Bar
# 215         Airport Food Court               Boutique       Harbor / Marina
# 216         Airport Food Court               Boutique       Harbor / Marina
# 217         Airport Food Court               Boutique       Harbor / Marina
# 218         Airport Food Court               Boutique       Harbor / Marina
# 219         Airport Food Court               Boutique       Harbor / Marina
# 220         Airport Food Court               Boutique       Harbor / Marina
# 221         Airport Food Court               Boutique       Harbor / Marina
# 238       Ethiopian Restaurant    Empanada Restaurant     Electronics Store
# 239                 Restaurant                  Hotel              Beer Bar
# 248         Italian Restaurant                    Pub                Bakery
# 249                       Park                  Diner        Breakfast Spot
# 250                      Hotel                    Bar   Japanese Restaurant
# 251                      Hotel                    Bar   Japanese Restaurant
# 261                 Restaurant            Men's Store             Gastropub
# 264             Farmers Market          Burrito Place         Auto Workshop
#
#            8th Most Common Venue        9th Most Common Venue  \
# 4                 Breakfast Spot        Performing Arts Venue
# 7                           Café           Chinese Restaurant
# 16                         Diner                    Bookstore
# 17                         Diner                    Bookstore
# 33            Italian Restaurant                     Beer Bar
# 46             Electronics Store  Eastern European Restaurant
# 47                   Cheese Shop                     Beer Bar
# 56                     Juice Bar             Department Store
# 57                    Restaurant                   Baby Store
# 67              Sushi Restaurant               Clothing Store
# 68              Sushi Restaurant               Clothing Store
# 69              Sushi Restaurant               Clothing Store
# 70                          Bank    Middle Eastern Restaurant
# 71                          Bank    Middle Eastern Restaurant
# 82                Scenic Lookout          Sporting Goods Shop
# 83                Scenic Lookout          Sporting Goods Shop
# 84                Scenic Lookout          Sporting Goods Shop
# 85                   Coffee Shop                      Brewery
# 86                   Coffee Shop                      Brewery
# 96                           Pub                  Pizza Place
# 97                           Pub                  Pizza Place
# 98                    Steakhouse                   Restaurant
# 99                    Steakhouse                   Restaurant
# 100                 Intersection                          Gym
# 101                 Intersection                          Gym
# 102                 Intersection                          Gym
# 112         Fast Food Restaurant           Italian Restaurant
# 113         Fast Food Restaurant           Italian Restaurant
# 114                   Steakhouse                    Gastropub
# 115                   Steakhouse                    Gastropub
# ..                           ...                          ...
# 182                          Gym                  Gas Station
# 183                       Bakery                     Beer Bar
# 184                       Bakery                     Beer Bar
# 185                Burrito Place                          Pub
# 186                Burrito Place                          Pub
# 195            Electronics Store  Eastern European Restaurant
# 196            Electronics Store  Eastern European Restaurant
# 197                       Bakery                          Bar
# 198                       Bakery                          Bar
# 199                       Bakery                          Bar
# 210                   Restaurant                  Supermarket
# 211                   Restaurant                  Supermarket
# 212                   Restaurant                  Supermarket
# 213                   Restaurant                  Supermarket
# 214                   Restaurant                  Supermarket
# 215                Boat or Ferry             Sculpture Garden
# 216                Boat or Ferry             Sculpture Garden
# 217                Boat or Ferry             Sculpture Garden
# 218                Boat or Ferry             Sculpture Garden
# 219                Boat or Ferry             Sculpture Garden
# 220                Boat or Ferry             Sculpture Garden
# 221                Boat or Ferry             Sculpture Garden
# 238  Eastern European Restaurant          Dumpling Restaurant
# 239           Italian Restaurant                 Cocktail Bar
# 248                  Pizza Place                    Pet Store
# 249           Italian Restaurant                     Beer Bar
# 250                    Gastropub                   Steakhouse
# 251                    Gastropub                   Steakhouse
# 261     Mediterranean Restaurant                         Café
# 264                  Pizza Place                          Spa
#
#     10th Most Common Venue
# 4             Dessert Shop
# 7    Portuguese Restaurant
# 16    Fast Food Restaurant
# 17    Fast Food Restaurant
# 33          Cosmetics Shop
# 46     Dumpling Restaurant
# 47            Liquor Store
# 56    Gym / Fitness Center
# 57             Coffee Shop
# 67         Thai Restaurant
# 68         Thai Restaurant
# 69         Thai Restaurant
# 70                 Brewery
# 71                 Brewery
# 82      Italian Restaurant
# 83      Italian Restaurant
# 84      Italian Restaurant
# 85             Record Shop
# 86             Record Shop
# 96            Liquor Store
# 97            Liquor Store
# 98               Gastropub
# 99               Gastropub
# 100            Yoga Studio
# 101            Yoga Studio
# 102            Yoga Studio
# 112          Burrito Place
# 113          Burrito Place
# 114    American Restaurant
# 115    American Restaurant
# ..                     ...
# 182                Brewery
# 183             Beer Store
# 184             Beer Store
# 185           Dessert Shop
# 186           Dessert Shop
# 195    Dumpling Restaurant
# 196    Dumpling Restaurant
# 197            Snack Place
# 198            Snack Place
# 199            Snack Place
# 210       Sushi Restaurant
# 211       Sushi Restaurant
# 212       Sushi Restaurant
# 213       Sushi Restaurant
# 214       Sushi Restaurant
# 215            Yoga Studio
# 216            Yoga Studio
# 217            Yoga Studio
# 218            Yoga Studio
# 219            Yoga Studio
# 220            Yoga Studio
# 221            Yoga Studio
# 238             Donut Shop
# 239         Breakfast Spot
# 248         Sandwich Place
# 249         Cosmetics Shop
# 250     Seafood Restaurant
# 251     Seafood Restaurant
# 261           Burger Joint
# 264                 Garden
#
# [74 rows x 16 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map of Toronto inserting clusters
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add borough markers to map
markers_colors = []
for lat, lng, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
